# %% [markdown]
# <a href="https://colab.research.google.com/github/P4CSS/PSS/blob/master/P01p_counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # P01-Pracitce01: Re-writing the department counting case
#
# 嘗試參考P01的案例教學，用`Counter()`改寫計算每個科系出現幾次的案例。

# %%
stu_list = ["soc", "soc", "econ", "bio", "psy", "psy", "econ", "poli", "econ"]

# %% [markdown]
# ## 簡單地印出所有的key與value
# ```
# Output：
# dict_keys(['soc', 'econ', 'bio', 'psy', 'poli'])
# dict_values([2, 3, 1, 2, 1])
# ```

# %% [markdown]
# ## 用for-loop印出每個科系的人數，由大而小
#
# ```
# Output:
# econ 3
# soc 2
# psy 2
# bio 1
# poli 1
# ```

# %% [markdown]
# # P01 Practice02 NTU's GPA Grading
# 參考「成績百分制轉等第制」的案例，參考[台大百分制轉等第的規定](https://www.aca.ntu.edu.tw/WebUPD/aca/UAADForms/%E7%AD%89%E7%AC%AC%E5%88%B6%E6%88%90%E7%B8%BE%E5%AE%9A%E7%BE%A9%E8%88%87%E7%AD%89%E7%AC%AC%E7%B8%BE%E5%88%86%E8%A1%A8.pdf)，寫出完整且合乎規定的百分制的轉換if-else邏輯判斷式。

# %% [markdown]
# 用for-loop列印出每個等第個有多少人？

# %% [markdown]
# # P01 Practice03 Sorting keyword frequency
# 仿照教學範例中最後一節的排序函式，將Wikipedia詞頻計算結果由大而小排序，並用for-loop將排序結果印出來。觀察一下，詞頻高的字詞有哪些呢？一共有三種寫法，請三種寫法都寫寫看。

# %%
import wikipedia    # import a 3rd-party library into runtime
string_a  = wikipedia.summary("Big_data", sentences = 10)   # get data by 3rd-party function

import string
translator = str.maketrans('','',string.punctuation)
string_a = string_a.translate(translator)
string_a = string_a.lower()

from collections import Counter
words = string_a.split()
word_freq = Counter(words)

# %%
# Method 1: sorting tuples

# %%
# Method 2: sort by dict.get()

# %%
# Method 3: sort by Counter's most_common() function
# Out:
# data 23
# and 15
# of 11
# to 9
# big 8
# the 8
# with 5
# that 4
# or 4
# analysis 4
# in 4
# analytics 4
# sets 3
# large 3
# a 3
# business 3
# devices 3
# refers 2
# are 2
# complex 2
# by 2
# software 2
# higher 2
# challenges 2
# information 2
# volume 2
# variety 2
# sampling 2
# thus 2
# for 2
# veracity 2
# can 2
# value 2
# from 2
# size 2
# is 2
# available 2
# new 2
# scientists 2
# including 2
# internet 2
# informatics 2
# as 2
# too 1
# be 1
# dealt 1
# traditional 1
# dataprocessing 1
# application 1
# many 1
# fields 1
# rows 1
# offer 1
# greater 1
# statistical 1
# power 1
# while 1
# complexity 1
# more 1
# attributes 1
# columns 1
# may 1
# lead 1
# false 1
# discovery 1
# rate 1
# include 1
# capturing 1
# storage 1
# search 1
# sharing 1
# transfer 1
# visualization 1
# querying 1
# updating 1
# privacy 1
# source 1
# was 1
# originally 1
# associated 1
# three 1
# key 1
# concepts 1
# velocity 1
# presents 1
# previously 1
# allowing 1
# only 1
# ...
