# %% [markdown]
# # Web Scraping
# - [slide](https://docs.google.com/presentation/d/1gn4d5gzXzgyEAIz_AOdM3pmJ0-6iiN7EbTjKqCQlgPo/edit?usp=sharing) for getting json data online
# - Finding data url
# - Scraping 104.com job info
# - Understanding how to send request and get back response
# - Send request with Cookie, payload, Referer...

# %% [markdown]
# # Library requests to send web requests
# * http://docs.python-requests.org/en/master/
# * Quickstart http://docs.python-requests.org/en/master/user/quickstart/

# %%
import requests
import json
response = requests.get('https://tcgbusfs.blob.core.windows.net/blobyoubike/YouBikeTP.gz')
print(response.json())

# %% [markdown]
# ## (Practice): Find out and traverse data behind urls

# %%
url_AQX = "https://taqm.epa.gov.tw/taqm/aqs.ashx?lang=tw&act=aqi-epa&ts=1538961147679"
url_dcard = "https://www.dcard.tw/_api/forums/relationship/posts?popular=true"
url_pchome = "http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=X100F&page=1&sort=rnk/dc"
url_cnyes = "https://news.cnyes.com/api/v3/news/category/headline?startAt=1588262400&endAt=1589212799&limit=30"

# Need Referer = https://www.104.com.tw/
url_104 = "https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc"

# POST
# url_sinyi = 'https://pixel-api.scupio.com/v0/event?cb=0.3497148401321104'

# %% [markdown]
# - (hint) Using `requests.get(url, timeout=(x, y))` to set the limitation of waiting time
# - `timeout=(x, y)`: Max x seconds to connect to server and max y seconds to wait on response
# - https://data.moi.gov.tw/moiod/System/Principle.aspx?Sample=2

# %%
res = requests.get(url_pchome, timeout=(3, 5)).json()
print(type(res))
# print(res.keys())
# Out:
# <class 'dict'>

# %% [markdown]
# ## (Option) Write a function to load json data

# %%
def get_web_json(url):
    response = requests.get(url, timeout=(3, 5))
    print("Response Code:", response.status_code)
    if not response.ok:
        return None
    data = response.json()
    return data

# %% [markdown]
# ## (Option) Check data type (list or dict)

# %%
data = get_web_json(url_dcard)
if isinstance(data, dict):
    print("A dict with", data.keys())
elif isinstance(data, list):
#     print("A list with the first data enetry\n", data[0])
    print(pd.DataFrame(data).head())
# Out:
# Response Code: 200
#           id           title  \
# 0  235615372  大學時期的情侶會走到最後嗎？
# 1  235619462     比基尼踩到男友媽媽的雷
# 2  235614768            幫男友弄
# 3  235615817   #更 長得漂亮講話卻很靠北
# 4  235614624          女友都不讀書
#
#                                              excerpt  anonymousSchool  \
# 0  大學時期的情侶到底會不會走到紅毯呢？最近看到很多朋友快畢業就一堆情侶分手，難道畢業就一定分手...             True
# 1  和男友在一起一年多，中間也去過不少玩水的地方，因為我本身蠻愛拍照的所以泳衣都穿比基尼居多，上...             True
# 2  男友有時候要我幫他弄，但是我第一次交男朋友，也是第一次幫別人用，所以我也不會...，他說他慢...             True
# 3  呃 我先聲明一下 這男的真的不是我，是這個女生跟一個男同事講，然後那個同事再跟我說，但我們兩...             True
# 4  女友是科大的 我是國立大學，一樣的科系，說好一起考證照國考，我兩個都上了，他都沒上，我罵他不...             True
#
#    anonymousDepartment  pinned                               forumId replyId  \
# 0                 True   False  42851318-b9e2-4a75-8a05-9fe180becefe    None
# 1                 True   False  42851318-b9e2-4a75-8a05-9fe180becefe    None
# 2                 True   False  42851318-b9e2-4a75-8a05-9fe180becefe    None
# 3                 True   False  42851318-b9e2-4a75-8a05-9fe180becefe    None
# 4                 True   False  42851318-b9e2-4a75-8a05-9fe180becefe    None
#
#                   createdAt                 updatedAt  ...  withImages  \
# 0  2021-03-24T03:48:27.181Z  2021-03-24T12:13:46.649Z  ...       False
# 1  2021-03-24T14:19:01.111Z  2021-03-24T14:19:01.111Z  ...        True
# 2  2021-03-24T01:43:04.246Z  2021-03-24T15:00:25.901Z  ...       False
# 3  2021-03-24T05:08:37.276Z  2021-03-24T15:47:30.502Z  ...       False
# 4  2021-03-24T00:58:12.318Z  2021-03-24T00:58:23.204Z  ...       False
#
#    withVideos                                              media  \
# 0       False                                                 []
# 1       False  [{'url': 'https://i.imgur.com/NCkuDyq.jpg'}, {...
# 2       False                                                 []
# 3       False                                                 []
# 4       False                                                 []
#
#   reportReasonText excerptComments postAvatar verifiedBadge categories  \
# 0                               []                    False        NaN
# 1                               []                    False        NaN
# 2                               []                    False        NaN
# 3                               []                    False        [更]
# 4                               []                    False        NaN
#
#    school department
# 0     NaN        NaN
# 1     NaN        NaN
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### (Practice) Adding type-checking code to the function

# %%
# Practice: Adding the type-checking code to the function

# %% [markdown]
# ### (Deprecated) Problmatic url? See requests doc
# * Try to get back the url https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1
# * You will get an 404 status_code
# ```
# url_591 = "https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=0&searchtype=1&region=1&section=12&firstRow=30&totalRows=495"
# response = requests.get(url_591)
# print(response.ok)
# print(response.status_code)
# ```
# * Solution: https://stackoverflow.com/questions/10606133/sending-user-agent-using-requests-library-in-python

# %% [markdown]
# # Scraping 104.com
# * Slide: https://docs.google.com/presentation/d/e/2PACX-1vRW84XoB5sFRT1Eg-GrK4smX23qoNkFffz_h8oRU4AIvJAgrrxBn8059_0UeHv_pFBks_Z37vNbLGai/pub?start=false&loop=false&delayms=3000
# ```
# https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc
# ```

# %% [markdown]
# ## 1. Get the first page, but fails

# %%
import requests
import json
url_104 = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc'
response = requests.get(url_104)

print(response.status_code)
print(response.text)
print(response.headers)
# Out:
# 200
# <html xmlns="http://www.w3.org/1999/xhtml"><head><META HTTP-EQUIV="CONTENT-TYPE" CONTENT="TEXT/HTML; CHARSET=utf-8"/><title></title></head>
# <body>
# <SCRIPT LANGUAGE="JavaScript">
# window.location="https://www.104.com.tw/jobs/main/syserr?eid=13584908623485849121";
# </script>
# </body>
# </html>
# {'Cache-Control': 'no-cache', 'Connection': 'close', 'Content-Type': 'text/html; charset=utf-8', 'Pragma': 'no-cache', 'Content-Length': '293'}

# %% [markdown]
# ### (Option) Write html to file

# %%
with open('temp_output.html', 'w') as fout:
    fout.write(response.text)
fout.close()

# webbrowser cannot work, but why?
import webbrowser
webbrowser.open_new_tab('temp_output.html')
# Out:
# True

# %% [markdown]
# ### (Practice) Observing youbike data headers
# Is is differnt from 104.com's?

# %%
import requests
import json
response = requests.get('https://tcgbusfs.blob.core.windows.net/blobyoubike/YouBikeTP.gz')
print(response)
print(response.status_code)
print(type(response)) # <class 'requests.models.Response'>
print(type(response.text)) # <class 'str'>
# Out:
# <Response [200]>
# 200
# <class 'requests.models.Response'>
# <class 'str'>

# %%
print(response.headers)
import pandas as pd
print(pd.DataFrame.from_dict(response.headers, orient='index'))
# Out:
# {'Content-Length': '32883', 'Content-Type': 'application/octet-stream', 'Content-Encoding': 'gzip', 'Content-MD5': '9hEmcORs/yynWSuu8p2Shg==', 'Last-Modified': 'Thu, 25 Mar 2021 03:57:01 GMT', 'ETag': '0x8D8EF420B809958', 'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0', 'x-ms-request-id': 'e41b4929-401e-011a-482a-2193e9000000', 'x-ms-version': '2009-09-19', 'x-ms-lease-status': 'unlocked', 'x-ms-blob-type': 'BlockBlob', 'Access-Control-Allow-Origin': '*', 'Date': 'Thu, 25 Mar 2021 03:57:27 GMT'}
#                                                                         0
# Content-Length                                                      32883
# Content-Type                                     application/octet-stream
# Content-Encoding                                                     gzip
# Content-MD5                                      9hEmcORs/yynWSuu8p2Shg==
# Last-Modified                               Thu, 25 Mar 2021 03:57:01 GMT
# ETag                                                    0x8D8EF420B809958
# Server                       Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0
# x-ms-request-id                      e41b4929-401e-011a-482a-2193e9000000
# x-ms-version                                                   2009-09-19
# x-ms-lease-status                                                unlocked
# x-ms-blob-type                                                  BlockBlob
# Access-Control-Allow-Origin                                             *
# Date                                        Thu, 25 Mar 2021 03:57:27 GMT

# %% [markdown]
# ## 2. Add referer to get back 104 data
# * User-Agent: 你用什麼瀏覽器或系統
# * Referer: 你從哪個頁面點選、跳轉過來
# * Cookies: 經過與伺服器建立連結後，他給了你什麼資訊好讓你持續可以待在這個頁面。

# %%
url_104 = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc'
# Out:
# <class 'dict'>

# %% [markdown]
# ## 3. Traverse data to get the data block

# %%
# Out:
# dict_keys(['status', 'action', 'data', 'statusMsg', 'errorMsg'])
# <class 'dict'>
# dict_keys(['query', 'filterDesc', 'queryDesc', 'list', 'count', 'pageNo', 'totalPage', 'totalCount'])
# <class 'list'>
# <class 'dict'>
#    jobType     jobNo                                            jobName  \
# 0        0  12025874                                     Data Scientist
# 1        0  11496984  派遣至LINE_Insight planner (data scientist、資料科學家、...
# 2        0  12136731                                  【A】Data Scientist
# 3        0  10589685                         Data Scientist 資料科學家_數據分析師
# 4        2   8229285                             [KKLab] Data Scientist
# 5        0  12049575                        資料科學家 Data Scientist (1-10)
# 6        2  11864977                                     Data Scientist
# 7        2  12135639                   Data Scientist (Network Science)
# 8        2  12135742           Senior Data Scientist (Machine Learning)
# 9        0   9597346                                     Data Scientist
# 10       0  11267645                     (Sr./Jr.) Data Scientist 資料科學家
# 11       0  11774964  Python programmer/data scientist for quantitat...
# 12       0  11903314              110年度研發替代役_Data Scientist 資料科學家_數據分析師
# 13       0  12104640                            Data Scientist Engineer
# 14       0  11310491                                     Data Scientist
# 15       2  12140803                             SA29878 Data Scientist
# 16       2  11913874               Data Scientist(Martech)- 工作地點: 內湖瑞光路
# 17       0  10703416         Senior Data Scientist (資深資料科學家, 此職務提供實習計畫)
# 18       2   9844049                  軟體類--Data Scientist Engineer (中科)
# 19       2   7461061                            Data Scientist_高雄_10408
#
#                                        jobNameSnippet jobRole jobRo  \
# 0   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 1   派遣至LINE_Insight planner (<em class='b-txt--hig...       1     1
# 2   【A】<em class='b-txt--highlight'>Data</em> <em ...       1     1
# 3   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 4   [KKLab] <em class='b-txt--highlight'>Data</em>...       1     1
# 5   <em class='b-txt--highlight'>資料科學家</em> <em cl...       1     1
# 6   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 7   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 8   Senior <em class='b-txt--highlight'>Data</em> ...       1     1
# 9   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 10  (Sr./Jr.) <em class='b-txt--highlight'>Data</e...       1     1
# 11  Python programmer/<em class='b-txt--highlight'...       1     1
# 12  110年度研發替代役_<em class='b-txt--highlight'>Data</...       1     1
# 13  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 14  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 15  SA29878 <em class='b-txt--highlight'>Data</em>...       4     1
# 16  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 17  Senior <em class='b-txt--highlight'>Data</em> ...       1     1
# 18  軟體類--<em class='b-txt--highlight'>Data</em> <e...       1     1
# 19  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
#
#      jobAddrNo jobAddrNoDesc      jobAddress  \
# 0   6001001007        台北市信義區   信義路四段415號5F之4
# 1   6001001010        台北市內湖區
# 2   6001002016        新北市土城區           民生街4號
# 3   6001002020        新北市三重區  三和路四段111之32號7樓
# 4   6001001011        台北市南港區      三重路19-3號一樓
# 5   6001001004        台北市松山區     南京東路五段89號9樓
# 6   6001001005        台北市大安區
# 7   6001001010        台北市內湖區   內湖路一段300號6樓之3
# 8   6001001010        台北市內湖區   內湖路一段300號6樓之3
# 9   6001001007        台北市信義區   基隆路一段200號9樓之1
# 10  6001001001        台北市中正區           仁愛路二段
# 11  6001001010        台北市內湖區       港墘路200號5樓
# 12  6001002020        新北市三重區  三和路四段111之32號7樓
# 13  6001002020        新北市三重區     重新路四段12號11樓
# 14  6001001003        台北市中山區     中山北路二段42號2樓
# 15  6001001009        台北市北投區         立德路115號
# 16  6001001010        台北市內湖區     瑞光路26巷20弄1號
# 17  6001001007        台北市信義區        東興路51號2樓
# 18  6001008020        台中市大雅區          科雅一路8號
# 19  6001016004        高雄市鹽埕區
#
#                                           description  ... isSave  \
# 0   尋找有應用程式大數據分析開發經驗的夥伴加入，開發腦科學研究資料分析軟體。有軟體架構經驗，能分...  ...      0
# 1   [Team/Position Description]\nInsight planner u...  ...      0
# 2   •Build production ready deep learning models\n...  ...      0
# 3   分群、推薦、迴歸預測等演算法理論基礎，並有實作經驗\r\n2. 熟悉程式與分析應用，如 Py...  ...      0
# 4    [[[data]]] management solutions.\n● We innova...  ...      0
# 5   《工作內容》\n於專案中進行分析建模開發規劃及設計工作，與系統分析師溝通確認如何實作需求，並...  ...      0
# 6    Engineering, or [[[Data]]] Science\n·      5+...  ...      0
# 7   NetBase Quid is searching for a talented and p...  ...      0
# 8   NetBase Quid is searching for a talented and p...  ...      0
# 9    with efficient and accurate tutor matching, c...  ...      0
# 10  展、布局全球，引領世界進入直播新媒體世代。\n\n歡迎對以下工作內容有興趣的 Sr./Jr....  ...      0
# 11  Python programmer/[[[data]]] [[[scientist]]] f...  ...      0
# 12  分群、推薦、迴歸預測等演算法理論基礎，並有實作經驗\r\n2. 熟悉程式與分析應用，如 Py...  ...      0
# 13  To be successful in this role you will need to...  ...      0
# 14  Design and tuning ML and mathematical models \...  ...      0
# 15  1. Identify valuable [[[data]]] sources and au...  ...      0
# 16  &lt;About the job&gt;：\nAs the [[[data]]] [[[s...  ...      0
# 17   maintenance\r\n2. Experience in analyzing and...  ...      0
# 18   system development\n2. Machine Learning / Dee...  ...      0
# 19  1.從事資料或影像分析相關工作內容：資料清理、特徵工程、資料視覺化及模型建立\r\n2.使用...  ...      0
#
#                                           descSnippet              tags  \
# 0   尋找有應用程式大數據分析開發經驗的夥伴加入，開發腦科學研究資料分析軟體。有軟體架構經驗，能分...                []
# 1   [Team/Position Description]\nInsight planner u...                []
# 2   •Build production ready deep learning models\n...                []
# 3   分群、推薦、迴歸預測等演算法理論基礎，並有實作經驗\r\n2. 熟悉程式與分析應用，如 Py...          [員工300人]
# 4    <em class='b-txt--highlight'>data</em> manage...          [員工600人]
# 5   《工作內容》\n於專案中進行分析建模開發規劃及設計工作，與系統分析師溝通確認如何實作需求，並...          [員工150人]
# 6    Engineering, or <em class='b-txt--highlight'>...           [員工80人]
# 7   NetBase Quid is searching for a talented and p...            [外商公司]
# 8   NetBase Quid is searching for a talented and p...            [外商公司]
# 9    with efficient and accurate tutor matching, c...           [員工70人]
# 10  展、布局全球，引領世界進入直播新媒體世代。\n\n歡迎對以下工作內容有興趣的 Sr./Jr....          [員工350人]
# 11  Python programmer/<em class='b-txt--highlight'...           [員工95人]
# 12  分群、推薦、迴歸預測等演算法理論基礎，並有實作經驗\r\n2. 熟悉程式與分析應用，如 Py...          [員工300人]
# 13  To be successful in this role you will need to...           [員工50人]
# 14  Design and tuning ML and mathematical models \...          [員工120人]
# 15  1. Identify valuable <em class='b-txt--highlig...            [上市上櫃]
# 16  &lt;About the job&gt;：\nAs the <em class='b-tx...   [上市上櫃, 員工8000人]
# 17   maintenance\r\n2. Experience in analyzing and...                []
# 18   system development\n2. Machine Learning / Dee...   [上市上櫃, 員工2800人]
# 19  1.從事資料或影像分析相關工作內容：資料清理、特徵工程、資料視覺化及模型建立\r\n2.使用...  [上市上櫃, 員工80000人]
#
#              landmark                                               link  \
# 0   距捷運台北101/世貿站340公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 1                      {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 2                      {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 3       距捷運三和國中站110公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 4      距捷運南港展覽館站290公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 5       距捷運南京三民站380公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 6       距捷運科技大樓站130公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 7         距捷運西湖站150公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 8         距捷運西湖站150公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 9        距捷運市政府站300公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 10        距捷運東門站470公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 11        距捷運港墘站470公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 12      距捷運三和國中站110公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 13        距捷運菜寮站440公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 14        距捷運中山站310公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 15        距捷運關渡站350公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 16                     {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 17                     {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 18                     {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 19       距捷運鹽埕埔站140公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
#
#              jobsource                                         jobNameRaw  \
# 0   jolist_a_relevance                                     Data Scientist
# 1   jolist_a_relevance  派遣至LINE_Insight planner (data scientist、資料科學家、...
# 2   jolist_a_relevance                                  【A】Data Scientist
# 3   jolist_a_relevance                         Data Scientist 資料科學家_數據分析師
# 4   jolist_a_relevance                             [KKLab] Data Scientist
# 5   jolist_a_relevance                        資料科學家 Data Scientist (1-10)
# 6   jolist_a_relevance                                     Data Scientist
# 7   jolist_a_relevance                   Data Scientist (Network Science)
# 8   jolist_a_relevance           Senior Data Scientist (Machine Learning)
# 9   jolist_a_relevance                                     Data Scientist
# 10  jolist_a_relevance                     (Sr./Jr.) Data Scientist 資料科學家
# 11  jolist_a_relevance  Python programmer/data scientist for quantitat...
# 12  jolist_a_relevance              110年度研發替代役_Data Scientist 資料科學家_數據分析師
# 13  jolist_a_relevance                            Data Scientist Engineer
# 14  jolist_a_relevance                                     Data Scientist
# 15  jolist_a_relevance                             SA29878 Data Scientist
# 16  jolist_a_relevance               Data Scientist(Martech)- 工作地點: 內湖瑞光路
# 17  jolist_a_relevance         Senior Data Scientist (資深資料科學家, 此職務提供實習計畫)
# 18  jolist_a_relevance                  軟體類--Data Scientist Engineer (中科)
# 19  jolist_a_relevance                            Data Scientist_高雄_10408
#
#                     custNameRaw          lon         lat
# 0                  康泰智能科技股份有限公司   121.559395   25.033408
# 1               萬寶華企業管理顧問股份有限公司  121.5909027  25.0689422
# 2             富智康國際股份有限公司(鴻海集團)  121.4143447  24.9613226
# 3                 伊雲谷數位科技股份有限公司  121.4856118  25.0774577
# 4              願境網訊股份有限公司_KKBOX  121.6132482  25.0565476
# 5                    偉康科技股份有限公司  121.5601021  25.0518161
# 6                    雲端互動股份有限公司  121.5433783  25.0249441
# 7               美商網基股份有限公司台灣分公司  121.5686754  25.0818595
# 8               美商網基股份有限公司台灣分公司  121.5686754  25.0818595
# 9                        知之有限公司   121.563553   25.040211
# 10  17LIVE_英屬維京群島商藝啟股份有限公司臺灣分公司  121.5293593  25.0381262
# 11                   中塑油品股份有限公司  121.5743267  25.0759802
# 12                伊雲谷數位科技股份有限公司  121.4856118  25.0774577
# 13                   雲馥數位股份有限公司  121.4887337  25.0576383
# 14                   台灣現觀股份有限公司   121.522377   25.054823
# 15                   華碩電腦股份有限公司  121.4704318  25.1267522
# 16           Advantech_研華股份有限公司  121.5826091  25.0693413
# 17                     行動貝果有限公司  121.5665022  25.0475591
# 18                   華邦電子股份有限公司  120.6190887  24.2119618
# 19                   緯創資通股份有限公司  120.2830007  22.6224414
#
# [20 rows x 38 columns]

# %% [markdown]
# ## 4. Get next page: get the 2nd, 1st, 3rd, ..., page urls
# ```
# https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc
#
# https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=1&mode=s&jobsource=2018indexpoc
#
# https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=3&mode=s&jobsource=2018indexpoc
# ```

# %%
for page in range(1, 6):
    # Your code should be here
# Out:
# 30
# 20
# 20
# 20
# 20

# %%
all_data = []
for page in range(1, 6):
    # Your code should be here
    
    
    
    print(len(all_data))

# %% [markdown]
# ### Convert to pandas DataFrame

# %%
df = pd.DataFrame(all_data)
print(df.shape)
print(len(set(df.jobNo)))
# Out:
# (110, 38)
# 96

# %% [markdown]
# ## 5. detect ending condition

# %%
# Out:
# dict_keys(['status', 'action', 'data', 'statusMsg', 'errorMsg'])
# <class 'dict'>
# dict_keys(['query', 'filterDesc', 'queryDesc', 'list', 'count', 'pageNo', 'totalPage', 'totalCount'])
# 2
# 150
# ['4544', '4320', '108', '14', '102', '0', '0']
# 4544

# %%
all_data = []
totalPage = 
for p in range(1, totalPage):

    
    
    
    print(len(all_data))

# %% [markdown]
# ## 6. convert to dataframe

# %%
df = pd.DataFrame(all_data)
print(df.shape)
df.head()
# Out:
# (1150, 38)
#   jobType     jobNo                                        jobName  \
# 0       1  10956171                                         高階主管秘書
# 1       1   8925036  設備工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)
# 2       1  11977925                   Product Marketing Specialist
# 3       1   9937464  設備工程師 - 南科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)
# 4       1   9226901  製程工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)
#
#                                   jobNameSnippet jobRole jobRo   jobAddrNo  \
# 0                                         高階主管秘書       1     1  6001001010
# 1  設備工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)       1     1  6001006001
# 2                   Product Marketing Specialist       1     1  6001001002
# 3  設備工程師 - 南科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)       1     1  6001014036
# 4  製程工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)       1     1  6001006001
#
#   jobAddrNoDesc   jobAddress  \
# 0        台北市內湖區     新湖二路8號5樓
# 1           新竹市
# 2        台北市大同區       近捷運中山站
# 3        台南市新市區  南科三路25號2樓之2
# 4           新竹市
#
#                                          description  ... isSave  \
# 0  此職務需要有高度敏銳、解決問題之能力，橫向溝通佳且善於表達。\n1.處理與主管相關的行政事務...  ...      0
# 1  Technical\r\n1. Responsible for providing qual...  ...      0
# 2  Roles &amp; Responsibilities\n• Maintain, impl...  ...      0
# 3  Technical\r\n 1. Responsible for providing qua...  ...      0
# 4  *請檢附英文履歷**請載明多益成績*\n\nTechnical\n1.Responsible...  ...      0
#
#                                          descSnippet            tags  \
# 0  此職務需要有高度敏銳、解決問題之能力，橫向溝通佳且善於表達。\n1.處理與主管相關的行政事務...              []
# 1  Technical\r\n1. Responsible for providing qual...  [外商公司, 員工850人]
# 2  Roles &amp; Responsibilities\n• Maintain, impl...              []
# 3  Technical\r\n 1. Responsible for providing qua...  [外商公司, 員工850人]
# 4  *請檢附英文履歷**請載明多益成績*\n\nTechnical\n1.Responsible...  [外商公司, 員工850人]
#
#      landmark                                               link   jobsource  \
# 0              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 1              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 2  距捷運中山站80公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 3              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 4              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
#
#                                       jobNameRaw                 custNameRaw  \
# 0                                         高階主管秘書                  偉太健康科技有限公司
# 1  設備工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)  美商_科林研發股份有限公司_Lam Research
# 2                   Product Marketing Specialist      ThunderCore_閃電核心科技有限公司
# 3  設備工程師 - 南科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)  美商_科林研發股份有限公司_Lam Research
# 4  製程工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)  美商_科林研發股份有限公司_Lam Research
#
#            lon         lat
# 0  121.5743893  25.0607141
# 1  120.9674798  24.8138287
# 2  121.5195662  25.0527276
# 3  120.2759224  23.0977104
# 4  120.9674798  24.8138287
#
# [5 rows x 38 columns]

# %% [markdown]
# # Dump files for backup

# %% [markdown]
# ## M1. Dump one variable to json by json library
# * https://docs.python.org/3/library/json.html

# %%
import json
with open('104_list.json', 'w') as outfile:
    json.dump(all_data, outfile)

# %% [markdown]
# ## M2. Dump and load json by pandas library

# %%
with open('104_df.json', 'w') as f:
    f.write(df.to_json())

# %%
with open("104_df.json") as fin:
    data2 = pd.read_json(fin)
data2.head()
# Out:
#    jobType     jobNo                                        jobName  \
# 0        1  10956171                                         高階主管秘書
# 1        1   8925036  設備工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)
# 2        1  11977925                   Product Marketing Specialist
# 3        1   9937464  設備工程師 - 南科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)
# 4        1   9226901  製程工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)
#
#                                   jobNameSnippet  jobRole  jobRo   jobAddrNo  \
# 0                                         高階主管秘書        1      1  6001001010
# 1  設備工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)        1      1  6001006001
# 2                   Product Marketing Specialist        1      1  6001001002
# 3  設備工程師 - 南科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)        1      1  6001014036
# 4  製程工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)        1      1  6001006001
#
#   jobAddrNoDesc   jobAddress  \
# 0        台北市內湖區     新湖二路8號5樓
# 1           新竹市
# 2        台北市大同區       近捷運中山站
# 3        台南市新市區  南科三路25號2樓之2
# 4           新竹市
#
#                                          description  ... isSave  \
# 0  此職務需要有高度敏銳、解決問題之能力，橫向溝通佳且善於表達。\n1.處理與主管相關的行政事務...  ...      0
# 1  Technical\r\n1. Responsible for providing qual...  ...      0
# 2  Roles &amp; Responsibilities\n• Maintain, impl...  ...      0
# 3  Technical\r\n 1. Responsible for providing qua...  ...      0
# 4  *請檢附英文履歷**請載明多益成績*\n\nTechnical\n1.Responsible...  ...      0
#
#                                          descSnippet            tags  \
# 0  此職務需要有高度敏銳、解決問題之能力，橫向溝通佳且善於表達。\n1.處理與主管相關的行政事務...              []
# 1  Technical\r\n1. Responsible for providing qual...  [外商公司, 員工850人]
# 2  Roles &amp; Responsibilities\n• Maintain, impl...              []
# 3  Technical\r\n 1. Responsible for providing qua...  [外商公司, 員工850人]
# 4  *請檢附英文履歷**請載明多益成績*\n\nTechnical\n1.Responsible...  [外商公司, 員工850人]
#
#      landmark                                               link   jobsource  \
# 0              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 1              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 2  距捷運中山站80公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 3              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
# 4              {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  hotjob_chr
#
#                                       jobNameRaw                 custNameRaw  \
# 0                                         高階主管秘書                  偉太健康科技有限公司
# 1  設備工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)  美商_科林研發股份有限公司_Lam Research
# 2                   Product Marketing Specialist      ThunderCore_閃電核心科技有限公司
# 3  設備工程師 - 南科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)  美商_科林研發股份有限公司_Lam Research
# 4  製程工程師 - 竹科 (濕蝕刻 Clean、蝕刻 Etch、薄膜沉積 Thin Film)  美商_科林研發股份有限公司_Lam Research
#
#           lon        lat
# 0  121.574389  25.060714
# 1  120.967480  24.813829
# 2  121.519566  25.052728
# 3  120.275922  23.097710
# 4  120.967480  24.813829
#
# [5 rows x 38 columns]

# %% [markdown]
# ## M3. Dump multiple variables to pickle

# %%
import pickle
with open('data/104.pkl', 'wb') as fout:  # Python 3: open(..., 'wb')
    pickle.dump([all_data, df], fout)

# %% [markdown]
# ### Load multiple variables back to objects

# %%
with open('data/104.pkl', "rb") as fin:  # Python 3: open(..., 'rb')
    test = pickle.load(fin)
    print(type(test[0]))
    print(type(test[1]))
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>

# %%
test[0][0].keys()
# Out:
# dict_keys(['jobType', 'jobNo', 'jobName', 'jobNameSnippet', 'jobRole', 'jobRo', 'jobAddrNo', 'jobAddrNoDesc', 'jobAddress', 'description', 'optionEdu', 'period', 'periodDesc', 'applyCnt', 'applyDesc', 'custNo', 'custName', 'coIndustry', 'coIndustryDesc', 'salaryLow', 'salaryHigh', 'salaryDesc', 's10', 'appearDate', 'appearDateDesc', 'optionZone', 'isApply', 'applyDate', 'isSave', 'descSnippet', 'tags', 'landmark', 'link', 'jobsource', 'jobNameRaw', 'custNameRaw', 'lon', 'lat'])

# %% [markdown]
# ## Using timestamp as file name

# %%
from datetime import datetime

now = datetime.now().strftime("%Y%m%d%H%M%S")
print("Current Time =", now)
with open('data/104_%s.pkl'%(now), 'wb') as fout:  # Python 3: open(..., 'wb')
    pickle.dump([all_data, df], fout)
# Out:
# Current Time = 20210325112321

# %% [markdown]
# # Clean version. 104

# %%
headers = {'referer': 'https://www.104.com.tw/'}
search_str = '數據分析'

# Detecting totalPage
url_104 = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=' + search_str + '&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc'
raw = requests.get(url_104, headers=headers).json()
totalPage = raw['data']['totalPage']
print(totalPage)

# Getting data by loop
all_data = []
for p in range(1, totalPage):
    url = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=' + search_str + '&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=' + str(page) + '&mode=s&jobsource=2018indexpoc'
    raw = requests.get(url, headers=headers).json()
    all_data.extend(raw['data']['list'])
    print(len(all_data))
df = pd.DataFrame(all_data)


# Saving and Backing up data
import pickle
from datetime import datetime

now = datetime.now().strftime("%Y%m%d%H%M%S")
print("Current Time =", now)
with open('data/104_%s_%s.pkl'%(search_str, now), 'wb') as fout:  # Python 3: open(..., 'wb')
    pickle.dump([all_data, df], fout)
