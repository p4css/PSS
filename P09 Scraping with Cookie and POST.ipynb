# %% [markdown]
# # Scraping with parameters
# [doc:requests](http://docs.python-requests.org/en/master/): http://docs.python-requests.org/en/master/

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Review: Adding referer for 104.com scraping

# %%
url_104 = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc'
headers = {'referer': 'https://www.104.com.tw/'}
raw = requests.get(url_104, headers=headers).json()
print(type(raw))
# Out:
# <class 'dict'>

# %% [markdown]
# # Passing Cookie for ptt crawler
# https://docs.python-requests.org/en/latest/user/quickstart/
# ```
# >>> url = 'https://httpbin.org/cookies'
# >>> cookies = dict(cookies_are='working')
#
# >>> r = requests.get(url, cookies=cookies)
# >>> r.text
# '{"cookies": {"cookies_are": "working"}}'
# ```

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
response = requests.get(url, timeout=(2, 3))
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# ...

# %% [markdown]
# ## Redirect history
# * http Status Code: https://www.restapitutorial.com/httpstatuscodes.html
#
# ```
# >>> r = requests.head('http://github.com/', allow_redirects=True)
#
# >>> r.url
# 'https://github.com/'
#
# >>> r.history
# [<Response [301]>]
# ```

# %%
response = requests.get(url, timeout=(1, 2))
response.history
# Out:
# [<Response [302]>]

# %%
print(response.cookies)
import pandas as pd
print(pd.DataFrame.from_dict(response.headers, orient='index'))
# Out:
# <RequestsCookieJar[]>
#                                                                            0
# Date                                           Thu, 08 Apr 2021 06:31:35 GMT
# Content-Type                                        text/html; charset=utf-8
# Transfer-Encoding                                                    chunked
# Connection                                                        keep-alive
# Alternate-Protocol                                            443:npn-spdy/3
# Strict-Transport-Security                                          max-age=0
# CF-Cache-Status                                                      DYNAMIC
# cf-request-id                               0951c6e8dd0000efb215b73000000001
# Expect-CT                  max-age=604800, report-uri="https://report-uri...
# Report-To                  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# NEL                                  {"max_age":604800,"report_to":"cf-nel"}
# ...

# %% [markdown]
# ## Adding cookies

# %%
cookies = {'over18': '1'}
res = requests.get(url, timeout=(1, 2), cookies = cookies)
res.text
# Out:
# '<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t\n\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>\n\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">\n\n\n\n\n\t</head>\n    <body>\n\t\t\n<div id="topbar-container">\n\t<div id="topbar" class="bbs-content">\n\t\t<a id="logo" href="/bbs/">批踢踢實業坊</a>\n\t\t<span>&rsaquo;</span>\n\t\t<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>\n\t\t<a class="right small" href="/about.ht
# ...

# %%
soup = BeautifulSoup(res.text, "html.parser")
for div in soup.find_all(class_ = "r-ent"):
    print(div.get_text(strip = True))
# Out:
# Re: [問卦] 火車前加一台前導車不行嗎？hotrain13⋯搜尋同標題文章搜尋看板內 hotrain13 的文章4/08
# 2[問卦] 出桶該做如何慶祝(沒錢)pearlsally⋯搜尋同標題文章搜尋看板內 pearlsally 的文章4/08
# Re: [問卦] 性向到底是先天還是後天的Lex4193⋯搜尋同標題文章搜尋看板內 Lex4193 的文章4/08
# [問卦] 如果宋岳庭和張雨生還在台灣音樂能走多r78213⋯搜尋同標題文章搜尋看板內 r78213 的文章4/08
# [問卦] 捐款後豪紳的錢怎麼處理啊？sula54⋯搜尋同標題文章搜尋看板內 sula54 的文章4/08
# 2[問卦] Afghanistan 為啥是翻阿富汗IMCENTER⋯搜尋同標題文章搜尋看板內 IMCENTER 的文章4/08
# [問卦] 大嬸的極限？ian81131⋯搜尋同標題文章搜尋看板內 ian81131 的文章4/08
# 13[公告] 八卦板板規(2020.11.21)arsonlolita⋯搜尋同標題文章搜尋看板內 arsonlolita 的文章11/21!
# 97[爆卦] 台鐵事故 傷患查詢系統(4/7 21:15更新)aaaaa6505⋯搜尋同標題文章搜尋看板內 aaaaa6505 的文章4/03
# X4[公告] 板規宣導-戰政治不戰板友arsonlolita⋯搜尋同標題文章搜尋看板內 arsonlolita 的文章4/04
# 24[協尋] 4/7 隨機攻擊路人事件 台師大全家旁a60310cool⋯搜尋同標題文章搜尋看板內 a60310cool 的文章4/07
# 15[協尋] （三峽）朋友舅舅林福三老先生走失請幫忙towar⋯搜尋同標題文章搜尋看板內 towar 的文章4/08

# %% [markdown]
# # POST
# https://docs.python-requests.org/en/master/user/quickstart/
# ```
# Requests’ simple API means that all forms of HTTP request are as obvious. For example, this is how you make an HTTP POST request:
#
# >>> r = requests.post('https://httpbin.org/post', data = {'key':'value'})
# Nice, right? What about the other HTTP request types: PUT, DELETE, HEAD and OPTIONS? These are all just as simple:
#
# >>> r = requests.put('https://httpbin.org/put', data = {'key':'value'})
# >>> r = requests.delete('https://httpbin.org/delete')
# >>> r = requests.head('https://httpbin.org/get')
# >>> r = requests.options('https://httpbin.org/get')
# ```

# %% [markdown]
# ## ibon

# %%
payloads = {'strTargetField':'COUNTY', 
            'strKeyWords':'台北市'}
url_ibon = 'http://www.ibon.com.tw/retail_inquiry_ajax.aspx'
raw = requests.post(url_ibon, data=payloads)
raw.text
# Out:
# '<table class="font16" width="100%" cellpadding="5" cellspacing="0" bgcolor="ffffff">    <tr>        <td width="20%" align="center" bgcolor="#c9e293" style="border:1px solid #fff; border-width:0 1px 1px 0;" class="black">店號 </td>        <td width="20%" align="center" bgcolor="#c9e293" style="border:1px solid #fff; border-width:0 1px 1px 0;" class="black">店名 </td>        <td align="center" bgcolor="#c9e293" style="border:1px solid #fff; border-width:0 1px 1px 0;" class="black"> 地址</td>    </tr><tr style="background-color:#FFFFFF;">    <td class="banner" style="cursor:pointer;font-size:large;" onclick="return SendProcess_Retail_Inquiry_ShowRetailInformation(\'110817\');" align="center"><a href="javascript:void(0)">110817</a></td>    <td align="center">千翔  </td>    <td>台北市中正區許昌街17號1樓                                   </td></tr><tr style="background-color:#E9E9E9;">    <td class="banner" style="cursor:pointer;font-size:large;" onclick="return SendProcess_Retail_Inquiry_ShowRetailInformat
# ...

# %% [markdown]
# ## Sinyi House (Failed)

# %%
payloads = {"machineNo":"",
            "ipAddress":"36.231.120.89",
            "osType":'4',
            "model":"web",
            "deviceVersion":"Mac OS X 11.2.3",
            "appVersion":"89.0.4389.114",
            "deviceType":'3',
            "apType":'3',
            "browser":'1',
            "memberId":"",
            "domain":"www.sinyi.com.tw",
            "utmSource":"",
            "utmMedium":"",
            "utmCampaign":"",
            "utmCode":"",
            "filter":{
                "exludeSameTrade":False,
                "objectStatus":"0",
                "retType":1,
                "retRange":["1"]},
            "requestor":'1',
            "utmContent":"",
            "utmTerm":"",
            "sinyiGroup":'1',
            "page":'3',
            "pageCnt":'20',
            "sort":"0",
            "isReturnTotal":True}

headers = {'referer': 'https://www.sinyi.com.tw/',
           'User-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36',
           'sid':'20201011212904134',
           'sat': '730282'}

cookies = {'PHPSESSID':'h4trime21bud2dv9j6khbnmme5',
           'lang':'tc',
           'expires':'Fri, 08-Apr-2022 07:32:22 GMT',
           'Max-Age':'31536000'}
url_sinyi = 'https://sinyiwebapi.sinyi.com.tw/searchObject.php'
# raw = requests.post(url_sinyi, data=payloads)
raw = requests.post(url_sinyi, data=payloads, headers = headers, cookies = cookies)
raw.text
# Out:
# '{"retResult":false,"retCode":"400","retMsg":"參數個數錯誤 139","debugMsg":"","content":null}'
